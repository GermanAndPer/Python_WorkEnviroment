# %% [markdown]
# # Entorno de Trabajo 👨‍💻🧪📄

# %% [markdown]
# ## WSL 🐧
# Comanpo para instalar WSL

# %%
# !wsl --install

# %% [markdown]
# ## PYTHON 🐍
#
# Cualquiera de los 2 siguientes comandos ayuda a saber la version de Python en la computadora

# %%
# !python --version
# !python3 --version

# %% [markdown]
# Una vez istalado correctamente WSL lo vamos a actualizar a la version mas reciente:
# * Actualizacion de Linux
# * Actualizacion de python
# * REvisar la version

# %%
# !sudo apt update
# !sudo apt upgrade
# !sudo apt-get -y install python3-pip
# !pip3 --version

# %% [markdown]
# ## VSC y WSL 🐧♾️
# Se continua con la istalacion de la extencion WSL en VSC:
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Cada que se vaya a hacer un trabajo con ___Python___ o ___Jupiter NoteBooks___ abrir la terminal de Linux y desde ahí ejecutar el siguiente codigo:

# %%
# !code .

# %% [markdown]
# # GITHUB 🦑🐈

# %% [markdown]
# ## 🗝️ Llave SSH
# Para poder hacer cualquier __actualizacion__ o __modificacion__ a archivos que tengas en tus repositorios de GITHUB de manera local, primero debes de **vincular** tu cuenta.
# Esto se puede hacer de varias maneras. Una de estas es mediante una llave SSH.
#
# Esta la generamos en ___nuestra propia computadora___.
#
# Al abrir la linea de comandos (En este caso linux) y ejecutar los siguietes comandos

# %%
# !ssh-keygen -t ed25519 -C "tu_correo@example.com"
# Se actualiza el correo por el propio.
# -t ed25519 establece el nivel de encriptación.
# -C añade un comentario con tu correo, útil para identificar la llave en GitHub.

# %% [markdown]
# ## 🗝️💾 Guardar llave :
#
# Despues de eso, nos pedirá un nombre.
# Preciona Enter para usar el nombre por defecto y añade una __contraseña segura__.
#
# La llave pública se guarda en el directorio .ssh, Al haber usado el nombre  predeterminado, aparecera nombrado:
#
# ```SH
# id_ed25519.pub
#
# ```
# Despues de eso, usamos los siguientes comandos para Configurar el agente SSH:
#
# * __Activa el agente de SSH__
#
# * __Añade la llave privada__

# %%
# !eval "$(ssh-agent -s)"
# !ssh-add ~/.ssh/id_ed25519
#En este punto te va ha pedir la contraseña

# %% [markdown]
# ## 🗝️ ¿Cómo añadir la llave SSH a GitHub?
# En el archivo de la llave pública ___(id_ed25519.pub)___ y copia el contenido.
#
# En ___GITHUB___, ve a Settings > SSH and GPG keys > New SSH key y pega la llave.
# Nombra la llave de acuerdo a la computadora en la que estás configurándola.
#
#
# ## 🗝️ ¿Cómo verificar la conexión con GitHub?
#
# Ejecuta el comando:

# %%
# !ssh -T git@github.com

# %% [markdown]
# En algunos casos te pedirá que confirmes conexion. ✅❌
#
# Solo es escribir “yes” para confirmar la conexión y después aparecerá un mensaje de GitHub que confirma la autenticidad.

# %% [markdown]
# ## 🔗 Conexion a repositorios
#
#
#
#
# ¿Cómo clonar un repositorio usando SSH?
#
# En __GitHub__, selecciona el repositorio deseado, elige la opción de __clonación__ por __SSH__ y __copia la URL__.
#
# ![image.png](attachment:image.png)
#
# En la terminal, ejecuta el siguiente comando __(Actualizando el link por el correspondiente al proyecto)__:

# %%
# !git clone git@github.com:usuario/repositorio.git

# %% [markdown]
# Esto clona el repositorio ___sin solicitar contraseña___ 🔐, aprovechando la autenticación SSH.
#
# Permitiendo ademas poder ___modificar nuestros repositorios___ ⚙️ al identificar que es nuestro propio usuario. 👤

# %% [markdown]
# ## 👨‍💻PROMPTS
#
# Una vez clonado el repositorio, la extension de GIT nos ayuda a poder hacer todas las modifiocaciones sin la linea de comandos.
#
# Haciendo que no sea tan necesario escribir las lineas.
#
# Pero en caso de que sí, estas con las mas utiles.
#
# * Para clonar un repositorio:

# %%
# !git clone git@github.com:usuario/repositorio.git

# %% [markdown]
# * Para agregar todos los archivos al Commit:

# %%
# !git add .

# %% [markdown]
# * Para mandar todos los cambios a la rama principal.

# %%
# !git push origin main
